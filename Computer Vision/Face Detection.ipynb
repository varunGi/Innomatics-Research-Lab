# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
faceCascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img = cv2.imread('modiji.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)                  # To avoid purple modiji
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1072.5, 658.5, -0.5)

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, 'gray')
plt.axis('off')
# Out:
# (-0.5, 1072.5, 658.5, -0.5)

# %% [markdown]
# from google
#
# color = cv2.imread("modiji.jpg",1 )
#
# gray = cv2.cvtColor(color, cv2.COLOR_RGB2GRAY)
# cv2.imwrite("gray.jpg", gray)
#
# b = color [:,:, 0]
# g = color [:,:, 1]
# r = color [:,:, 2]
#
# rgba = cv2.merge((b,g,r, g))
# cv2.imwrite("rgba.png", rgba)

# %%
img_gray.shape
# Out:
# (659, 1073)

# %%
faces=faceCascade.detectMultiScale(img_gray,1.2,4)
faces
# Out:
# array([[419, 102, 247, 247]])

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+h,y + w), (255,0,0), 3)
    
plt.imshow(img)

# %%
#creating a function
def detect_face(image):
    faceCascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    img=cv2.imread(image)
    img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
    faces=faceCascade.detectMultiScale(img_gray,1.2,4)
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+h,y + w), (255,0,0), 3)
    return img

# %%
image=detect_face('modiji.jpg')
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1072.5, 658.5, -0.5)

# %%
# whole code
def detect_face(image):
    faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    img = cv2.imread(image)
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    faces = faceCascade.detectMultiScale(img_gray, 1.2, 4)
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x,y), (x+h,y + w), (255,0,0), 3)
    
    return img

# %%
image = detect_face('modiji.jpg')
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1072.5, 658.5, -0.5)

# %%
image = detect_face('rdj.jpg')
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 810.5, -0.5)
