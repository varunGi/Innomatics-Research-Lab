# %%
#high end data visualisation library

# %%
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#draw line plot 
sns.lineplot(data.sepal_length,data.sepal_width)
# Out:
# C:\Users\Varshith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=data)
plt.show()

# %%
sns.lineplot(x='sepal_length',y='sepal_width',data=data)
plt.xlim(5)
plt.ylim(3)
sns.set_style('dark')
plt.show()

# %%
plt.subplot(2,1,1)
sns.lineplot(x='sepal_length',y='sepal_width',data=data)
sns.set_style('dark')
plt.show()
plt.subplot(2,1,2)
sns.lineplot(x='petal_length',y='petal_width',data=data)
sns.set_style('white')
plt.show()

# %% [markdown]
# # Color palette

# %%
palette=sns.color_palette()
sns.palplot(palette)
plt.show()

# %%
p=sns.color_palette('Blues',9)
sns.palplot(p)
plt.show()

# %%
p=sns.color_palette('Reds',10)
sns.palplot(p)
plt.show()

# %% [markdown]
# Relatinal Plots

# %%
#relpot()
#these are used for visualizing the statistical relationship between the Data points

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal_width',y='species',data=data)
plt.show()

# %%
sns.relplot(x='sepal_width',y='petal_width',data=data)
plt.show()

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=data)
plt.show()

# %%
#categorical plots

# %%
#bar plot

# %%
sns.barplot(x='species',y='sepal_length',data=data)
plt.show()

# %%
#countplot()---------counts the categories and returns a count of their occurances

# %%
sns.countplot(x='species',data=data)
plt.show()

# %%
#box

# %%
sns.boxplot(x='sepal_width',y='species',data=data)
plt.show()

# %%
#distplot

# %%
sns.distplot(data['sepal_width'])
plt.show()
# Out:
# C:\Users\Varshith\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#pairplots

# %%
#represents pairswise relation acrosss the entire datta frame and supports an additional argument called hue
#for categorical separation

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=data,hue='species')
plt.show()

# %%
#heat map

# %%
c=data.corr()
sns.heatmap(c)
plt.show()

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
table=pd.pivot_table(df,index=['who'])

# %%
table
# Out:
#        adult_male        age     alone       fare     parch    pclass  \
# who
# child         0.0   6.369518  0.072289  32.785795  1.265060  2.626506
# man           1.0  33.173123  0.763501  24.864182  0.152700  2.372439
# woman         0.0  32.000000  0.446494  46.570711  0.564576  2.084871
#
#           sibsp  survived
# who
# child  1.734940  0.590361
# man    0.296089  0.163873
# woman  0.601476  0.756458

# %%
table=pd.pivot_table(df,index=['who','alive'],aggfunc=np.sum)

# %%
table
# Out:
#              adult_male       age  alone        fare  parch  pclass  sibsp  \
# who   alive
# child no              0    245.50      2   1109.5459     48     100    103
#       yes             0    283.17      4   1611.6751     57     118     41
# man   no            449  11247.50    346   9649.3405     71    1102    136
#       yes            88   2453.00     64   3702.7251     11     172     23
# woman no              0   1492.50     26   1383.8335     62     188     65
#       yes             0   5483.50     95  11236.8292     91     377     98
#
#              survived
# who   alive
# child no            0
#       yes          49
# man   no            0
#       yes          88
# woman no            0
#       yes         205

# %%
c=df[['fare','pclass','parch']].corr()
sns.heatmap(c)
plt.show()

# %%
df.groupby('embark_town').count()
# Out:
#              survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# embark_town
# Cherbourg         168     168  168  130    168    168   168       168    168
# Queenstown         77      77   77   28     77     77    77        77     77
# Southampton       644     644  644  554    644    644   644       644    644
#
#              who  adult_male  deck  alive  alone
# embark_town
# Cherbourg    168         168    69    168    168
# Queenstown    77          77     4     77     77
# Southampton  644         644   128    644    644
