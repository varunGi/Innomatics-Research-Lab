# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('50_Startups.csv')
df.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %% [markdown]
# - Independent Feature:R&D Spend,Administration,Marketing Spend,State
# - Dependent Feature:Profit

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
print('States : ', df['State'].unique())
# Out:
# States :  ['New York' 'California' 'Florida']

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.scatterplot('R&D Spend', 'Profit', data = df)
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Profit'>

# %%
plt.figure(figsize = (14, 6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot("State","Profit",data=df)
plt.subplot(1,2,2)
sns.boxplot("State","Profit",data=df)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
plt.figure(figsize = (14, 6), dpi = 200)

plt.subplot(1,2,1)
sns.distplot(df['Profit'], hist = False)

plt.subplot(1,2,2)
sns.boxplot(y = 'Profit', data = df)
# Out:
# <AxesSubplot:ylabel='Profit'>

# %%
plt.figure(figsize = (14, 6), dpi = 200)
sns.scatterplot(x='Administration',y = 'Profit', data = df)
# Out:
# <AxesSubplot:xlabel='Administration', ylabel='Profit'>

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.scatterplot('Marketing Spend', 'Profit', data = df)
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Profit'>

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.lineplot('Marketing Spend', 'Profit', data = df)
# Out:
# <AxesSubplot:xlabel='Marketing Spend', ylabel='Profit'>

# %%
plt.figure(figsize = (18,6), dpi = 300)

plt.subplot(1,3,1)
sns.boxplot(y = 'R&D Spend', data = df)

plt.subplot(1,3,2)
sns.boxplot(y = 'Marketing Spend', data = df)

plt.subplot(1,3,3)
sns.boxplot(y = 'Administration', data = df)
# Out:
# <AxesSubplot:ylabel='Administration'>

# %%
X=df[['R&D Spend', 'Administration', 'Marketing Spend', 'State']].values
Y=df[["Profit"]].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
Y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [3])], remainder = 'passthrough')
X = ct.fit_transform(X)
X
# Out:
# array([[0.0, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [0.0, 1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [1.0, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [0.0, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [1.0, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [0.0, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1.0, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [1.0, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
# ...

# %%
print('Independent Feature Set Shape : ', X.shape)
print('Dependent Feature Set Shape   : ', Y.shape)
# Out:
# Independent Feature Set Shape :  (50, 6)
# Dependent Feature Set Shape   :  (50, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 5)

# %%
print('Training Data Shape   : ', x_train.shape)
print('Training Labels Shape : ', y_train.shape)
print('Testing Data Shape    : ', x_test.shape)
print('Testing Labels Shape  : ', y_test.shape)
# Out:
# Training Data Shape   :  (37, 6)
# Training Labels Shape :  (37, 1)
# Testing Data Shape    :  (13, 6)
# Testing Labels Shape  :  (13, 1)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[ 7.65031203e+02,  2.45868839e+02, -1.01090004e+03,
#          7.81494897e-01, -2.84329206e-02,  3.85924982e-02]])

# %%
reg.intercept_
# Out:
# array([48948.84340212])

# %%
print("Score on training data : ",reg.score(x_train,y_train))
print("Score on testing data : ",reg.score(x_test,y_test))
# Out:
# Score on training data :  0.9409373492550397
# Score on testing data :  0.9701993496424649

# %%
reg.predict([[0,0,1,100000,120000,140000]])
# Out:
# array([[128078.43231671]])

# %%
#array([[4.11074778e+09]])

# %%
def predict_profit(state,rd,admin,marketing):
    data={'Newyork' : [0,0,1],'Florida' : [0,1,0],'California' : [1,0,0]}
    inp=data[state]
    inp.extend([rd,admin,marketing])
    inp=np.array(inp).reshape(1,-1)
    print(inp)
    profit=reg.predict(inp)
    print('The Profit is : ',int(profit[0][0]))

# %%
predict_profit("Newyork",100000,120000,140000)
# Out:
# [[     0      0      1 100000 120000 140000]]
# The Profit is :  128078

# %%
predict_profit("California",100000,120000,140000)
# Out:
# [[     1      0      0 100000 120000 140000]]
# The Profit is :  129854

# %%
predict_profit("Florida",100000,120000,140000)
# Out:
# [[     0      1      0 100000 120000 140000]]
# The Profit is :  129335

# %%
predict_profit("Florida",200000,120000,140000)
# Out:
# [[     0      1      0 200000 120000 140000]]
# The Profit is :  207484
